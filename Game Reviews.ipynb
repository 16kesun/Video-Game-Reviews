# %%
import pandas as pd

# %%
df = pd.read_csv("Video_Games_Sales_as_at_22_Dec_2016.csv.zip")

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
# Name               16717 non-null object
# Platform           16719 non-null object
# Year_of_Release    16450 non-null float64
# Genre              16717 non-null object
# Publisher          16665 non-null object
# NA_Sales           16719 non-null float64
# EU_Sales           16719 non-null float64
# JP_Sales           16719 non-null float64
# Other_Sales        16719 non-null float64
# Global_Sales       16719 non-null float64
# Critic_Score       8137 non-null float64
# Critic_Count       8137 non-null float64
# User_Score         10015 non-null object
# User_Count         7590 non-null float64
# Developer          10096 non-null object
# Rating             9950 non-null object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
df['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
df.loc[df['Publisher'] == 'Nintendo']
# Out:
#                                                     Name Platform  \
# 0                                             Wii Sports      Wii
# 1                                      Super Mario Bros.      NES
# 2                                         Mario Kart Wii      Wii
# 3                                      Wii Sports Resort      Wii
# 4                               Pokemon Red/Pokemon Blue       GB
# 5                                                 Tetris       GB
# 6                                  New Super Mario Bros.       DS
# 7                                               Wii Play      Wii
# 8                              New Super Mario Bros. Wii      Wii
# 9                                              Duck Hunt      NES
# 10                                            Nintendogs       DS
# 11                                         Mario Kart DS       DS
# 12                           Pokemon Gold/Pokemon Silver       GB
# ...

# %%
#create console wars dataframe
consoles = ['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
       'PS4', '3DS', 'N64', 'PS', 'XB','PSP', 'XOne',
       'WiiU', 'GC','PSV']
df_wars = df.loc[df['Platform'].isin(consoles)]
df_wars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15327 entries, 0 to 16718
# Data columns (total 16 columns):
# Name               15327 non-null object
# Platform           15327 non-null object
# Year_of_Release    15092 non-null float64
# Genre              15327 non-null object
# Publisher          15279 non-null object
# NA_Sales           15327 non-null float64
# EU_Sales           15327 non-null float64
# JP_Sales           15327 non-null float64
# Other_Sales        15327 non-null float64
# Global_Sales       15327 non-null float64
# Critic_Score       7408 non-null float64
# Critic_Count       7408 non-null float64
# User_Score         9182 non-null object
# User_Count         6806 non-null float64
# Developer          9254 non-null object
# Rating             9162 non-null object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
df_PS4 = df.loc[df['Platform'] == 'PS4']
df_PS4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 393 entries, 31 to 16589
# Data columns (total 16 columns):
# Name               393 non-null object
# Platform           393 non-null object
# Year_of_Release    393 non-null float64
# Genre              393 non-null object
# Publisher          393 non-null object
# NA_Sales           393 non-null float64
# EU_Sales           393 non-null float64
# JP_Sales           393 non-null float64
# Other_Sales        393 non-null float64
# Global_Sales       393 non-null float64
# Critic_Score       252 non-null float64
# Critic_Count       252 non-null float64
# User_Score         263 non-null object
# User_Count         257 non-null float64
# Developer          273 non-null object
# Rating             255 non-null object
# dtypes: float64(9), object(7)
# memory usage: 52.2+ KB

# %%
df_Xone = df.loc[df['Platform'] == 'XOne']
summary_lst = ['Global_Sales','Critic_Score','User_Count']
empty_lst = []
for feature in summary_lst:
    empty_lst.append(df_Xone[feature].mean())
dictionary = dict(zip(summary_lst,empty_lst))
dictionary
# Out:
# {'Global_Sales': 0.645506072874494,
#  'Critic_Score': 73.32544378698225,
#  'User_Count': 285.7692307692308}

# %%
def get_console(console):
    df_console = df.loc[df['Platform'] == console]
    summary_lst = ['Global_Sales','Critic_Score','User_Count']
    empty_lst = []
    for feature in summary_lst:
        empty_lst.append(df_console[feature].mean())
    dictionary = dict(zip(summary_lst,empty_lst))
    return dictionary

# %%
get_console('XOne'), get_console('PS4')
# Out:
# ({'Global_Sales': 0.645506072874494,
#   'Critic_Score': 73.32544378698225,
#   'User_Count': 285.7692307692308},
#  {'Global_Sales': 0.7995674300254428,
#   'Critic_Score': 72.09126984126983,
#   'User_Count': 518.1556420233463})

# %%
print("a")
# Out:
# a
